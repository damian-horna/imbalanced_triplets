# %%
from multi_imbalance.datasets import load_datasets
import experiment_v2 as ex
from sklearn.model_selection import StratifiedKFold
from collections import Counter, defaultdict
from multi_imbalance.utils.metrics import gmean_score
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from utils import plot_embeddings
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# %%
datasets = load_datasets()

# %%
ds_name = 'dermatology'
test_on_all_folds = True
test_all_ds = True

# %%
datasets = ex.one_hot_encode_all(datasets)

# %%
from experiment import dt_name_to_cols_to_encode, dt_name_minority_classes

# %%
from sklearn.neighbors import KNeighborsClassifier

def calc_safety_minority_majority_5(X,y, minority_classes):
    result_minority = {
        "safe":0,
        "borderline":0,
        "rare":0,
        "outlier":0
    }
    
    result_majority = {
        "safe":0,
        "borderline":0,
        "rare":0,
        "outlier":0
    }
    
    result = {True: result_minority, False: result_majority}
    
    
    neigh = KNeighborsClassifier(n_neighbors=5)
    neigh.fit(X, y)
    neighbors = neigh.kneighbors(X, 5+1, False)
    
    for i, (x, nbors) in enumerate(list(zip(X, neighbors))):
        same_class_nbrs = (y[nbors[1:]] == y[i]).sum()
        
        cond = y[i] in minority_classes
        
        if same_class_nbrs >= 4:
            result[cond]['safe'] += 1
        elif same_class_nbrs >= 2:
            result[cond]['borderline'] += 1
        elif same_class_nbrs == 1:
            result[cond]['rare'] += 1
        else:
            result[cond]['outlier'] += 1
    return result[True], result[False]

# %%
def standardize(X_train, X_test):
    means = X_train.mean(axis=0)
    stds = X_train.std(axis=0)
    return (X_train - means) / (stds+1e-6), (X_test - means) / (stds + 1e-6)

# %%
result_dict = defaultdict(list)

safety_dict = defaultdict(list)

if test_all_ds:
    ds_names = dt_name_to_cols_to_encode.keys()
else:
    ds_names = [ds_name]
    
for dataset_name in ds_names:
# for dataset_name in list(datasets.keys()):
    print(dataset_name)
    
    safety_dict["dataset"].append(dataset_name)
    

    X, y = datasets[dataset_name]['data'], datasets[dataset_name]['target']
    X_encoded, y = datasets[f"{dataset_name}_encoded"]['data'], datasets[f"{dataset_name}_encoded"]['target']
    
    X_encoded, _ = standardize(X_encoded, X_encoded)
    
    minority_classes = dt_name_minority_classes[dataset_name]
    
    number_of_minority_examples = sum([label in minority_classes for label in y])
        
    s_dict_minority, s_dict_majority = calc_safety_minority_majority_5(X_encoded, y, minority_classes)
    for k,v in s_dict_minority.items():
        safety_dict[f"minority-{k}"].append(v / number_of_minority_examples)
        
    for k,v in s_dict_majority.items():
        safety_dict[f"majority-{k}"].append(v / (X_encoded.shape[0] - number_of_minority_examples))
# Out:
# cmc
# dermatology
# hayes-roth
# new_vehicle
# new_yeast
# 1czysty-cut
# 2delikatne-cut
# 3mocniej-cut
# 4delikatne-bezover-cut
# balance-scale
# cleveland
# cleveland_v2
# glass
# new_ecoli
# new_led7digit
# new_winequality-red
# thyroid-newthyroid

# %%
safety_df = pd.DataFrame.from_dict(safety_dict)

# %%
safety_df[sorted(safety_df.filter(regex=("dataset|minority")).columns)].style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
# #T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow0_col1,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col1,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow2_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow3_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow4_col2,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow5_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow6_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow7_col1,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow8_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow9_col2,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow10_col3,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow11_col3,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow12_col1,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow13_col4,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow14_col1,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow15_col3,#T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow16_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dataset</th>        <th class="col_heading level0 col1" >minority-borderline</th>        <th class="col_heading level0 col2" >minority-outlier</th>        <th class="col_heading level0 col3" >minority-rare</th>        <th class="col_heading level0 col4" >minority-safe</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow0_col0" class="data row0 col0" >cmc</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow0_col1" class="data row0 col1" >0.477477</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow0_col2" class="data row0 col2" >0.213213</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow0_col3" class="data row0 col3" >0.192192</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow0_col4" class="data row0 col4" >0.117117</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col0" class="data row1 col0" >dermatology</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col1" class="data row1 col1" >0.450000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col3" class="data row1 col3" >0.100000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow1_col4" class="data row1 col4" >0.450000</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow2_col0" class="data row2 col0" >hayes-roth</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow2_col1" class="data row2 col1" >0.451613</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow2_col4" class="data row2 col4" >0.548387</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow3_col0" class="data row3 col0" >new_vehicle</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow3_col1" class="data row3 col1" >0.146283</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow3_col2" class="data row3 col2" >0.004796</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow3_col3" class="data row3 col3" >0.023981</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow3_col4" class="data row3 col4" >0.824940</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow4_col0" class="data row4 col0" >new_yeast</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow4_col1" class="data row4 col1" >0.266667</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow4_col2" class="data row4 col2" >0.350000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow4_col3" class="data row4 col3" >0.161111</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow4_col4" class="data row4 col4" >0.222222</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow5_col0" class="data row5 col0" >1czysty-cut</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow5_col1" class="data row5 col1" >0.077778</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow5_col2" class="data row5 col2" >0.000000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow5_col3" class="data row5 col3" >0.000000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow5_col4" class="data row5 col4" >0.922222</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow6_col0" class="data row6 col0" >2delikatne-cut</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow6_col1" class="data row6 col1" >0.330556</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow6_col2" class="data row6 col2" >0.055556</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow6_col3" class="data row6 col3" >0.130556</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow6_col4" class="data row6 col4" >0.483333</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow7_col0" class="data row7 col0" >3mocniej-cut</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow7_col1" class="data row7 col1" >0.350000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow7_col2" class="data row7 col2" >0.150000</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow7_col3" class="data row7 col3" >0.291667</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow7_col4" class="data row7 col4" >0.208333</td>
#             </tr>
#             <tr>
#                         <th id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164blevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow8_col0" class="data row8 col0" >4delikatne-bezover-cut</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow8_col1" class="data row8 col1" >0.230556</td>
#                         <td id="T_c79949ae_c643_11eb_a7b6_b1bc01a1164brow8_col2" class="data row8 col2" >0.041667</td>

# %%
safety_df[sorted(safety_df.filter(regex=("dataset|majority")).columns)].style.highlight_max(color = 'lightgreen', axis = 1)
# Out:
# <style  type="text/css" >
# #T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow0_col1,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow1_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow2_col1,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow3_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow4_col1,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow5_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow6_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow7_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow8_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow9_col1,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow10_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow11_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow12_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow13_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow14_col4,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow15_col1,#T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow16_col4{
#             background-color:  lightgreen;
#         }</style><table id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >dataset</th>        <th class="col_heading level0 col1" >majority-borderline</th>        <th class="col_heading level0 col2" >majority-outlier</th>        <th class="col_heading level0 col3" >majority-rare</th>        <th class="col_heading level0 col4" >majority-safe</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow0_col0" class="data row0 col0" >cmc</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow0_col1" class="data row0 col1" >0.524561</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow0_col2" class="data row0 col2" >0.074561</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow0_col3" class="data row0 col3" >0.221053</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow0_col4" class="data row0 col4" >0.179825</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow1_col0" class="data row1 col0" >dermatology</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow1_col1" class="data row1 col1" >0.173410</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow1_col2" class="data row1 col2" >0.011561</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow1_col3" class="data row1 col3" >0.028902</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow1_col4" class="data row1 col4" >0.786127</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow2_col0" class="data row2 col0" >hayes-roth</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow2_col1" class="data row2 col1" >0.775194</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow2_col3" class="data row2 col3" >0.038760</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow2_col4" class="data row2 col4" >0.186047</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow3_col0" class="data row3 col0" >new_vehicle</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow3_col1" class="data row3 col1" >0.111888</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow3_col2" class="data row3 col2" >0.002331</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow3_col3" class="data row3 col3" >0.027972</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow3_col4" class="data row3 col4" >0.857809</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow4_col0" class="data row4 col0" >new_yeast</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow4_col1" class="data row4 col1" >0.425613</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow4_col2" class="data row4 col2" >0.110429</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow4_col3" class="data row4 col3" >0.180215</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow4_col4" class="data row4 col4" >0.283742</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow5_col0" class="data row5 col0" >1czysty-cut</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow5_col1" class="data row5 col1" >0.039286</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow5_col2" class="data row5 col2" >0.000000</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow5_col3" class="data row5 col3" >0.010714</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow5_col4" class="data row5 col4" >0.950000</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow6_col0" class="data row6 col0" >2delikatne-cut</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow6_col1" class="data row6 col1" >0.115476</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow6_col2" class="data row6 col2" >0.003571</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow6_col3" class="data row6 col3" >0.014286</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow6_col4" class="data row6 col4" >0.866667</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow7_col0" class="data row7 col0" >3mocniej-cut</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow7_col1" class="data row7 col1" >0.265476</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow7_col2" class="data row7 col2" >0.001190</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow7_col3" class="data row7 col3" >0.010714</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow7_col4" class="data row7 col4" >0.722619</td>
#             </tr>
#             <tr>
#                         <th id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164blevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow8_col0" class="data row8 col0" >4delikatne-bezover-cut</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow8_col1" class="data row8 col1" >0.132143</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a1164brow8_col2" class="data row8 col2" >0.005952</td>
#                         <td id="T_c79cbad0_c643_11eb_a7b6_b1bc01a116
